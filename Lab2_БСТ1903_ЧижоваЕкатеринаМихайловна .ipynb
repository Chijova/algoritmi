# %% [markdown]
# # Лабораторная работа №2
# ## Выполнила студентка группы БСТ1903 Чижова Екатерина Михайловна
# Реализовать методы поиска в соответствии с заданием. Организовать генерацию
# начального набора случайных данных. Для всех вариантов добавить реализацию
# добавления, поиска и удаления элементов. Оценить время работы каждого алгоритма
# поиска и сравнить его со временем работы стандартной функции поиска, используемой в
# выбранном языке программирования.
# ### Задание №1
# Бинарный поиск Бинарное дерево Фибоначчиев Интерполяционный

# %%
def random_arr(m = 50, min_limit = -250, max_limit = 1020):
    import random
    return [random.randint(min_limit, max_limit) for _ in range(m)]

# %%
def BinSearch(arr, x):
    i = 0
    j = len(arr)-1
    while i < j:
        m = int((i+j)/2)
        if x > arr[m]:
            i = m+1
        else:
            j = m
    return j

# %%
newMatrix = random_arr(15, -25, 100)
newMatrix.sort()
print (newMatrix)
k=10
g=BinSearch(newMatrix, k)
if newMatrix[g] == k:
    print ("Это элемент под номером ",g)
else: print ("Данного элемента в массиве нет")
print ("Хотите добавить данный элемент в массив? Введите да или нет ")
s=(input())
if s == "да":
    newMatrix.insert(g, k)
    print (newMatrix)
if newMatrix[g] == k: 
    print ("Хотите удалить данный элемент из массива? Введите да или нет ")
    s=(input())
    if s == "да":
        newMatrix.pop(g)
        print (newMatrix)
# Out:
# [-23, -1, 26, 56, 57, 66, 67, 73, 74, 81, 82, 82, 83, 88, 89]
# Данного элемента в массиве нет
# Хотите добавить данный элемент в массив? Введите да или нет
# нет

# %%
class Node:

    def __init__(self, data):
        self.left = None
        self.right = None
        self.data = data

    def insert(self, data):
        if self.data:
            if data < self.data:
                if self.left is None:
                    self.left = Node(data)
                else:
                    self.left.insert(data)
            elif data > self.data:
                if self.right is None:
                    self.right = Node(data)
                else:
                    self.right.insert(data)
        else:
            self.data = data

    def search(self, lkpval):
        if lkpval < self.data:
            if self.left is None:
                return str(lkpval)+" Not Found"
            return self.left.findval(lkpval)
        elif lkpval > self.data:
            if self.right is None:
                return str(lkpval)+" Not Found"
            return self.right.findval(lkpval)
        else:
            print(str(self.data) + ' is found')
            return (self.data)
    def deleted (self, id):
        a=search(id)
        if self.right is not None:
            self.data=self.right.data
            deleted(self.right)
        elif self.left is not None:
            self.data=self.left.data
            deleted(self.left)
        elif (self.left is None) and (self.right is None):
            del(self)

    def PrintTree(self):
        if self.left:
            self.left.PrintTree()
        print( self.data),
        if self.right:
            self.right.PrintTree()
            


root = Node(12)
root.insert(6)
root.insert(14)
root.insert(3)
root.insert(5)
print(root.search(7))
print(root.search(14))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-79-fd0275d16120> in <module>
#      58 root.insert(3)
#      59 root.insert(5)
# ---> 60 print(root.search(7))
#      61 print(root.search(14))
#
# <ipython-input-79-fd0275d16120> in search(self, lkpval)
#      25             if self.left is None:
#      26                 return str(lkpval)+" Not Found"
# ---> 27             return self.left.findval(lkpval)
#      28         elif lkpval > self.data:
#      29             if self.right is None:
#
# AttributeError: 'Node' object has no attribute 'findval'

# %%
class Node:

    def __init__(self, data):

        self.left = None
        self.right = None
        self.data = data

    def insert(self, data):
        if self.data:
            if data < self.data:
                if self.left is None:
                    self.left = Node(data)
                else:
                    self.left.insert(data)
            elif data > self.data:
                if self.right is None:
                    self.right = Node(data)
                else:
                    self.right.insert(data)
        else:
            self.data = data

    def search(self, lkpval):
        if lkpval < self.data:
            if self.left is None:
                return str(lkpval)+" Not Found"
            return self.left.search(lkpval)
        elif lkpval > self.data:
            if self.right is None:
                return str(lkpval)+" Not Found"
            return self.right.search(lkpval)
        else:
            return str(self.data) + ' is found'
            
    def deleted (self, nod):
        self=self.search(nod)
        if self.right is not None:
            self.data=self.right.data
            return self.right.deleted(nod)
        elif self.left is not None:
            self.data=self.left.data
            deleted(self.left)
        elif (self.left is None) and (self.right is None):
            del(nod)

    def PrintTree(self):
        if self.left:
            self.left.PrintTree()
        print( self.data),
        if self.right:
            self.right.PrintTree()


root = Node(12)
root.insert(6)
root.insert(14)
root.insert(3)
root.insert(5)
root.insert(8)
root.insert(14)
root.insert(32)
root.PrintTree()
print(root.search(1))
print(root.search(32))
# Out:
# 3
# 5
# 6
# 8
# 12
# 14
# 32
# 1 Not Found
# 32 is found

# %%
def fibMonaccianSearch(arr, x, n):
    fibMMm2 = 0 # (м-2) -ый номер Фибоначчи
    fibMMm1 = 1  
    fibM = fibMMm2 + fibMMm1 # m'th Фибоначчи
    while (fibM < n):
        fibMMm2 = fibMMm1
        fibMMm1 = fibM
        fibM = fibMMm2 + fibMMm1
    offset = -1;
    while (fibM > 1):
        i = min(offset+fibMMm2, n-1)
        if (arr[i] < x):
            fibM = fibMMm1
            fibMMm1 = fibMMm2
            fibMMm2 = fibM - fibMMm1
            offset = i
        elif (arr[i] > x):
            fibM = fibMMm2
            fibMMm1 = fibMMm1 - fibMMm2
            fibMMm2 = fibM - fibMMm1
        else :
            return i
    if(fibMMm1 and arr[offset+1] == x):
        return offset+1;
    return offset+1

# %%
newMatrix = random_arr(15, -25, 100)
newMatrix.sort()
print (newMatrix)
k=3
n=len(newMatrix)
g=fibMonaccianSearch(newMatrix, k, n)
if newMatrix[g] == k:
    print ("Это элемент под номером ",g)
else: print ("Данного элемента в массиве нет")
print ("Хотите добавить данный элемент в массив? Введите да или нет ")
s=(input())
if s == "да":
    newMatrix.insert(g, k)
    print (newMatrix)
if newMatrix[g] == k: 
    print ("Хотите удалить данный элемент из массива? Введите да или нет ")
    s=(input())
    if s == "да":
        newMatrix.pop(g)
        print (newMatrix)
# Out:
# [-12, -9, 1, 6, 21, 30, 31, 32, 53, 64, 65, 68, 74, 77, 80]
# Данного элемента в массиве нет
# Хотите добавить данный элемент в массив? Введите да или нет
# да
# [-12, -9, 1, 3, 6, 21, 30, 31, 32, 53, 64, 65, 68, 74, 77, 80]
# Хотите удалить данный элемент из массива? Введите да или нет
# нет

# %%
def interpolation(a, k) : 
    left = 0  
    right = len(a) - 1  
    while a[left] < k and k < a[right]:
        mid = int(left + (k - a[left]) * (right - left) / (a[right] - a[left]))  
        if a[mid] < k:
            left = mid + 1
        elif a[mid] > k:
            right = mid - 1
        else:
            return mid

    if a[left] == k:
        return left
    elif a[right] == k:
        return right
    else:
        return left

# %%
newMatrix = random_arr(15, -25, 100)
newMatrix.sort()
print (newMatrix)
k=3
g=interpolation(newMatrix, k)
if newMatrix[g] == k:
    print ("Это элемент под номером ",g)
else: print ("Данного элемента в массиве нет")
print ("Хотите добавить данный элемент в массив? Введите да или нет ")
s=(input())
if s == "да":
    newMatrix.insert(g, k)
    print (newMatrix)
if newMatrix[g] == k: 
    print ("Хотите удалить данный элемент из массива? Введите да или нет ")
    s=(input())
    if s == "да":
        newMatrix.pop(g)
        print (newMatrix)
# Out:
# [-13, -8, -7, -5, 1, 6, 32, 43, 56, 60, 61, 69, 69, 87, 91]
# Данного элемента в массиве нет
# Хотите добавить данный элемент в массив? Введите да или нет
# да
# [-13, -8, -7, -5, 1, 3, 6, 32, 43, 56, 60, 61, 69, 69, 87, 91]
# Хотите удалить данный элемент из массива? Введите да или нет
# да
# [-13, -8, -7, -5, 1, 6, 32, 43, 56, 60, 61, 69, 69, 87, 91]

# %% [markdown]
# ### Задание №2
# Простое рехэширование
# Рехэширование с помощью псевдослучайных чисел
# Метод цепочек

# %%
class HashMap:
    def __init__(self):
        self.rhash={}
    def Hash (self, id):
        hash=0
        for i in range(len(id)):
            hash=hash+ord(id[i])
        return hash%256

    def search (self, id):
        hash=self.Hash(id);
        while self.rhash.get(hash) is not None:
            if self.rhash[hash]==id:
                return hash
            hash = hash+1
        print ("Идентификатор не найден")
        return None
    def insert (self, id):
        hash=self.Hash(id);
        while self.rhash.get(hash) is not None:
            hash = hash+1
        self.rhash[hash]=id
    def Print (self):
        for key, i in self.rhash.items():
            print ("Ключ ", key, "Элемент ", i)

# %%
a=HashMap()
print ("Хотите добавить новый идентификатор в таблицу? Введите да или нет ")
s=(input())
if s == "да":
    while s =="да":
        id=(input())
        a.insert(id)
        print ("Хотите добавить новый идентификатор в таблицу? Введите да или нет ")
        s=(input())
a.Print()
print ("Хотите найти идентификатор в таблице? Введите да или нет ")
k=(input())
if k == "да":
    while k =="да":
        id=(input())
        hash =a.search (id)
        print ("Элемент номер ", hash)
        print ("Хотите найти идентификатор в таблице? Введите да или нет ")
        k=(input())
# Out:
# Хотите добавить новый идентификатор в таблицу? Введите да или нет
# да
# да
# Хотите добавить новый идентификатор в таблицу? Введите да или нет
# да
# да
# Хотите добавить новый идентификатор в таблицу? Введите да или нет
# да
# да
# Хотите добавить новый идентификатор в таблицу? Введите да или нет
# да
# да
# Хотите добавить новый идентификатор в таблицу? Введите да или нет
# да
# да
# Хотите добавить новый идентификатор в таблицу? Введите да или нет
# нет
# Ключ  100 Элемент  да
# Ключ  101 Элемент  да
# Ключ  102 Элемент  да
# Ключ  103 Элемент  да
# Ключ  104 Элемент  да
# Хотите найти идентификатор в таблице? Введите да или нет
# нет

# %%
import random
class RandomHashMap:
    def __init__ (self):
        self.rhash={}
    def rand(self, i):
        random.seed(i)
        return int((random.random()*10000000000000000)%1000)
    def Fhash (self, id, i):
        import random
        hash=self.rand(i)
        for i in range(len(id)):
            hash=hash+ord(id[i])
        return hash%256
    def insert (self, element):
        i=int(0)
        hash=self.Fhash(id, i)
        while self.rhash.get(hash) is not None:
            hash=(hash-self.rand(i))+self.rand(i+1)
            i=i+1
        self.rhash[hash]=id;
    def search(self, id):
        i=int(0)
        hash=self.Fhash(id, i)
        while self.rhash.get(hash) is not None:
            if self.rhash[hash]==id:
                return hash
            else:
                hash=(hash-self.rand(i))+self.rand(i+1)
            i=i+1
        return None
    def pr(self):
        for hash, id in self.rhash.items():
            print("хэш", hash, "Элемент", id)

# %%
a=RandomHashMap()
print ("Хотите добавить новый идентификатор в таблицу? Введите да или нет ")
s=(input())
if s == "да":
    while s =="да":
        id=(input())
        a.insert (id)
        print ("Хотите добавить новый идентификатор в таблицу? Введите да или нет ")
        s=(input())
a.pr()
print ("Хотите найти идентификатор в таблице? Введите да или нет ")
k=(input())
if k == "да":
    while k =="да":
        id=(input())
        hash =a.search (id)
        print (hash)
        print ("Хотите найти идентификатор в таблице? Введите да или нет ")
        k=(input())
# Out:
# Хотите добавить новый идентификатор в таблицу? Введите да или нет
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-67-10e1afa5092c> in <module>
#       1 a=RandomHashMap()
#       2 print ("Хотите добавить новый идентификатор в таблицу? Введите да или нет ")
# ----> 3 s=(input())
#       4 if s == "да":
#       5     while s =="да":
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#     858                 "raw_input was called, but this frontend does not support input requests."
#     859             )
# --> 860         return self._input_request(str(prompt),
#     861             self._parent_ident,
#     862             self._parent_header,
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 904                 raise KeyboardInterrupt("Interrupted by user") from None
#     905             except Exception as e:
#     906                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
class ChainMap:
    def __init__(self):
        self.rhash={}
    def insert (self, id):
        h=0
        for i in range (0, len(id)):
            h=ord(id[i])+h
        key=h%10
        if self.rhash.get(key) is not None:
            elem=self.rhash[key]
            elem.append(id)
            self.rhash[key]=elem
        else:
            a=[id]
            self.rhash[key]=a
        return key
    def Search (self, id):
        h=0
        for i in range (0, len(id)):
            h=ord(id[i])+h
        key=h%10
        if self.rhash.get(key) is not None:
            elem=self.rhash[key]
            for i in range (len(elem)):
                if elem[i]==id:
                    return key, i
        return None
    def delete(self, id):
        key, i=self.Search(id)
        if key is not None:
            elem=self.rhash[key]
            del(elem[i])
            self.rhash[key]=elem
            return 1
        else:
            return -1
    def pr(self):
        for hash, id in self.rhash.items():
            print("хэш", hash, "Элемент", id)

# %%
a=ChainMap()
print ("Хотите добавить новый идентификатор в таблицу? Введите да или нет ")
s=(input())
if s == "да":
    while s =="да":
        id=(input())
        x=a.insert (id)
        print ("Хотите добавить новый идентификатор в таблицу? Введите да или нет ")
        s=(input())
a.pr()
print ("Хотите найти идентификатор в таблице? Введите да или нет ")
k=(input())
if k == "да":
    while k =="да":
        id=(input())
        hash =a.Search ( id)
        print ("Хотите найти идентификатор в таблице? Введите да или нет ")
        k=(input())
    if hash!= 1:
        print ("Хотите удалить идентификатор из таблицы? Введите да или нет ")
        k=(input())
        if k == "да":
            hash =a.delete (id)
# Out:
# Хотите добавить новый идентификатор в таблицу? Введите да или нет
# да
# часпаро
# Хотите добавить новый идентификатор в таблицу? Введите да или нет
# да
# про
# Хотите добавить новый идентификатор в таблицу? Введите да или нет
# нет
# хэш 9 Элемент ['часпаро']
# хэш 1 Элемент ['про']
# Хотите найти идентификатор в таблице? Введите да или нет
# да
# про
# Хотите найти идентификатор в таблице? Введите да или нет
# нет
# Хотите удалить идентификатор из таблицы? Введите да или нет
# да

# %%
def chessboard(data):
    row = lambda i: ''.join([
        tag('<span style="font-size:24px">♛</span>' * v,
            color='white' if (i+j+1)%2 else 'darkgray')
        for j, v in enumerate(data[i])])
    tb = ''.join([f'<tr>{tag(8-i)}{row(i)}{tag(8-i)}</tr>' for i in range(len(data))])
    return HTML(f'<table>{th}{tb}{th}</table>')

# %%
from IPython.display import HTML, display
import random
import time
def tag(x, color='white'):
    return f'<td style="width:24px;height:24px;text-align:center;" bgcolor="{color}">{x}</td>'
th = ''.join(map(tag, ' abcdefgh '))

# %%
def check_place(rows, row, column):
    """ Проверяет, если board[column][row] под атакой других ферзей """
    for i in range(row):
        if rows[i] == column or \
            rows[i] - i == column - row or \
            rows[i] + i == column + row:
            return False
    return True

total_shown = 0
def put_queen(rows=[0]*8, row=0):
    if row == 8:
        arr = [[0] * 8 for i in range(8)]
        for row, column in enumerate(rows):
            arr[row][column] = 1
        return chessboard(arr)
    else:
        for column in range(8):
            if check_place(rows, row, column):
                rows[row] = column
                board = put_queen(rows, row + 1)
                if board: return board
    
put_queen()
# Out:
# <table><td style="width:24px;height:24px;text-align:center;" bgcolor="white"> </td><td style="width:24px;height:24px;text-align:center;" bgcolor="white">a</td><td style="width:24px;height:24px;text-align:center;" bgcolor="white">b</td><td style="width:24px;height:24px;text-align:center;" bgcolor="white">c</td><td style="width:24px;height:24px;text-align:center;" bgcolor="white">d</td><td style="width:24px;height:24px;text-align:center;" bgcolor="white">e</td><td style="width:24px;height:24px;text-align:center;" bgcolor="white">f</td><td style="width:24px;height:24px;text-align:center;" bgcolor="white">g</td><td style="width:24px;height:24px;text-align:center;" bgcolor="white">h</td><td style="width:24px;height:24px;text-align:center;" bgcolor="white"> </td><tr><td style="width:24px;height:24px;text-align:center;" bgcolor="white">8</td><td style="width:24px;height:24px;text-align:center;" bgcolor="white"><span style="font-size:24px">♛</span></td><td style="width:24px;height:24px;text-align:center;" bgcolor="darkgray"></td><td style="width:24px;height:24px;text-align:center;" bgcolor="white"></td><td style="width:24px;height:24px;text-align:center;" bgcolor="darkgray"></td><td style="width:24px;height:24px;text-align:center;" bgcolor="white"></td><td style="width:24px;height:24px;text-align:center;" bgcolor="darkgray"></td><td style="width:24px;height:24px;text-align:center;" bgcolor="white"></td><td style="width:24px;height:24px;text-align:center;" bgcolor="darkgray"></td><td style="width:24px;height:24px;text-align:center;" bgcolor="white">8</td></tr><tr><td style="width:24px;height:24px;text-align:center;" bgcolor="white">7</td><td style="width:24px;height:24px;text-align:center;" bgcolor="darkgray"></td><td style="width:24px;height:24px;text-align:center;" bgcolor="white"></td><td style="width:24px;height:24px;text-align:center;" bgcolor="darkgray"></td><td style="width:24px;height:24px;text-align:center;" bgcolor="white"></td><td style="width:24px;height:24px;text-align:center;" bgcolor="darkgray"><span style="font-size:24px">♛</span></td><td style="width:24px;height:24px;text-align:center;" bgcolor="white"></td><td style="width:24px;height:24px;text-align:center;" bgcolor="darkgray"></td><td style="width:24px;height:24px;text-align:center;" bgcolor="white"></td><td style="width:24px;height:24px;text-align:center;" bgcolor="white">7</td></tr><tr><td style="width:24px;height:24px;text-align:center;" bgcolor="white">6</td><td style="width:24px;height:24px;text-align:center;" bgcolor="white"></td><td style="width:24px;height:24px;text-align:center;" bgcolor="darkgray"></td><td style="width:24px;height:24px;text-align:center;" bgcolor="white"></td><td style="width:24px;height:24px;text-align:center;" bgcolor="darkgray"></td><td style="width:24px;height:24px;text-align:center;" bgcolor="white"></td><td style="width:24px;height:24px;text-align:center;" bgcolor="darkgray"></td><td style="width:24px;height:24px;text-align:center;" bgcolor="white"></td><td style="width:24px;height:24px;text-align:center;" bgcolor="darkgray"><span style="font-size:24px">♛</span></td><td style="width:24px;height:24px;text-align:center;" bgcolor="white">6</td></tr><tr><td style="width:24px;height:24px;text-align:center;" bgcolor="white">5</td><td style="width:24px;height:24px;text-align:center;" bgcolor="darkgray"></td><td style="width:24px;height:24px;text-align:center;" bgcolor="white"></td><td style="width:24px;height:24px;text-align:center;" bgcolor="darkgray"></td><td style="width:24px;height:24px;text-align:center;" bgcolor="white"></td><td style="width:24px;height:24px;text-align:center;" bgcolor="darkgray"></td><td style="width:24px;height:24px;text-align:center;" bgcolor="white"><span style="font-size:24px">♛</span></td><td style="width:24px;height:24px;text-align:center;" bgcolor="darkgray"></td><td style="width:24px;height:24px;text-align:center;" bgcolor="white"></td><td style="width:24px;height:24px;text-align:center;" bgcolor="white">5</t ...
